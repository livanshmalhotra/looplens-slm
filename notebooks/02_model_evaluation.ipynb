# %% [markdown]
# # 02. LoopLens SLM Model Evaluation & Accuracy Benchmarking
#
# This notebook evaluates fine-tuned LoRA adapters on UNSPSC exact match, 4-level taxonomy accuracy, vendor entity resolution precision, and strict JSON format compliance.

# %%
from src.evaluate import evaluate_predictions
import os

# Evaluate prediction output file
eval_path = "../outputs/benchmark_temp.jsonl"
if os.path.exists(eval_path):
    evaluate_predictions(eval_path)
else:
    print("Run benchmark inference first to populate prediction outputs.")
